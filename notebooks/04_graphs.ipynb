# %% [markdown]
# # Graphs
# > Embedding and classifying graphs with hyperbolic decision trees
#
# Based on https://geomstats.github.io/notebooks/13_real_world_applications__graph_embedding_and_clustering_in_hyperbolic_space.html#

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install geomstats
# !pip install networkx
# !pip install torch
# !pip install torch_geometric
# Out:
# Requirement already satisfied: geomstats in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: joblib>=0.17.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from geomstats) (1.3.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from geomstats) (3.7.2)
# Requirement already satisfied: numpy>=1.18.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from geomstats) (1.24.4)
# Requirement already satisfied: pandas>=1.1.5 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from geomstats) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from geomstats) (1.3.0)
# Requirement already satisfied: scipy>=1.9 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from geomstats) (1.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from matplotlib>=3.3.4->geomstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from pandas>=1.1.5->geomstats) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from pandas>=1.1.5->geomstats) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from scikit-learn>=0.22.1->geomstats) (3.1.0)
# Requirement already satisfied: six>=1.5 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->geomstats) (1.16.0)
# Requirement already satisfied: networkx in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (3.1)
# Requirement already satisfied: torch in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: filelock in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.8.0)
# Requirement already satisfied: wheel in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: cmake in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from triton==2.0.0->torch) (3.27.0)
# Requirement already satisfied: lit in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: torch_geometric in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: tqdm in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: numpy in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (1.24.4)
# Requirement already satisfied: scipy in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (1.11.1)
# Requirement already satisfied: jinja2 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (2.29.0)
# Requirement already satisfied: pyparsing in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (1.3.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from torch_geometric) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from jinja2->torch_geometric) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from requests->torch_geometric) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from requests->torch_geometric) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from requests->torch_geometric) (2023.5.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from scikit-learn->torch_geometric) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages (from scikit-learn->torch_geometric) (3.1.0)

# %%
import logging
import pickle as pkl

import numpy as np
import matplotlib.pyplot as plt

import networkx as nx

import geomstats.backend as gs
import geomstats.visualization as visualization

from geomstats.datasets.utils import load_karate_graph
from geomstats.geometry.poincare_ball import PoincareBall
# Out:
# INFO: Using numpy backend

# %%
# Hyperparameters and data loading

gs.random.seed(1234)
dim = 2
max_epochs = 100
lr = 0.05
n_negative = 2
context_size = 1
karate_graph = load_karate_graph()

# %%
# Convert geomstats graph to networkx graph; visualize

karate_graph_nx = nx.Graph()
nodes = []
edges = []
for key in karate_graph.edges:
    nodes.append(key)
    for edge in karate_graph.edges[key]:
        edges.append([key, edge])
karate_graph_nx.add_nodes_from(nodes)
karate_graph_nx.add_edges_from(edges)

nx.draw_networkx(
    karate_graph_nx,
    with_labels=True,
    node_color=[karate_graph.labels[x][0] for x in nodes],
)

# %%
# Embed

hyperbolic_manifold = PoincareBall(2)


def grad_squared_distance(point_a, point_b):
    """Gradient of squared hyperbolic distance.

    Gradient of the squared distance based on the
    Ball representation according to point_a

    Parameters
    ----------
    point_a : array-like, shape=[n_samples, dim]
        First point in hyperbolic space.
    point_b : array-like, shape=[n_samples, dim]
        Second point in hyperbolic space.

    Returns
    -------
    dist : array-like, shape=[n_samples, 1]
        Geodesic squared distance between the two points.
    """
    log_map = PoincareBall(2).metric.log(point_b, point_a)

    return -2 * log_map


def log_sigmoid(vector):
    """Logsigmoid function.

    Apply log sigmoid function

    Parameters
    ----------
    vector : array-like, shape=[n_samples, dim]

    Returns
    -------
    result : array-like, shape=[n_samples, dim]
    """
    return gs.log((1 / (1 + gs.exp(-vector))))


def grad_log_sigmoid(vector):
    """Gradient of log sigmoid function.

    Parameters
    ----------
    vector : array-like, shape=[n_samples, dim]

    Returns
    -------
    gradient : array-like, shape=[n_samples, dim]
    """
    return 1 / (1 + gs.exp(vector))


def loss(example_embedding, context_embedding, negative_embedding, manifold):
    """Compute loss and grad.

    Compute loss and grad given embedding of the current example,
    embedding of the context and negative sampling embedding.
    """
    n_edges, dim = negative_embedding.shape[0], example_embedding.shape[-1]
    example_embedding = gs.expand_dims(example_embedding, 0)
    context_embedding = gs.expand_dims(context_embedding, 0)
    positive_distance = manifold.metric.squared_dist(
        example_embedding, context_embedding
    )
    positive_loss = log_sigmoid(-positive_distance)

    reshaped_example_embedding = gs.repeat(example_embedding, n_edges, axis=0)
    negative_distance = manifold.metric.squared_dist(
        reshaped_example_embedding, negative_embedding
    )
    negative_loss = log_sigmoid(negative_distance)

    total_loss = -(positive_loss + negative_loss.sum())

    positive_log_sigmoid_grad = -grad_log_sigmoid(-positive_distance)

    positive_distance_grad = grad_squared_distance(
        example_embedding, context_embedding
    )

    positive_grad = (
        gs.repeat(positive_log_sigmoid_grad, dim, axis=-1)
        * positive_distance_grad
    )

    negative_distance_grad = grad_squared_distance(
        reshaped_example_embedding, negative_embedding
    )

    negative_distance = gs.to_ndarray(negative_distance, to_ndim=2, axis=-1)
    negative_log_sigmoid_grad = grad_log_sigmoid(negative_distance)

    negative_grad = negative_log_sigmoid_grad * negative_distance_grad
    example_grad = -(positive_grad + negative_grad.sum(axis=0))

    return total_loss, example_grad


# Embed


def embed_graph(graph):
    nb_vertices_by_edges = [len(e_2) for _, e_2 in graph.edges.items()]

    embeddings = gs.random.normal(size=(graph.n_nodes, dim))
    embeddings = embeddings * 0.2
    random_walks = graph.random_walk()
    negative_table_parameter = 5
    negative_sampling_table = []

    for i, nb_v in enumerate(nb_vertices_by_edges):
        negative_sampling_table += (
            [i] * int((nb_v ** (3.0 / 4.0))) * negative_table_parameter
        )

    negative_sampling_table = gs.array(negative_sampling_table)

    for epoch in range(max_epochs):
        total_loss = []
        for path in random_walks:

            for example_index, one_path in enumerate(path):
                context_index = path[
                    max(0, example_index - context_size) : min(
                        example_index + context_size, len(path)
                    )
                ]
                negative_index = gs.random.randint(
                    negative_sampling_table.shape[0],
                    size=(len(context_index), n_negative),
                )
                negative_index = negative_sampling_table[negative_index]

                example_embedding = embeddings[one_path]
                for one_context_i, one_negative_i in zip(
                    context_index, negative_index
                ):
                    context_embedding = embeddings[one_context_i]
                    negative_embedding = embeddings[one_negative_i]
                    l, g_ex = loss(
                        example_embedding,
                        context_embedding,
                        negative_embedding,
                        hyperbolic_manifold,
                    )
                    total_loss.append(l)

                    example_to_update = embeddings[one_path]
                    embeddings[one_path] = hyperbolic_manifold.metric.exp(
                        -lr * g_ex, example_to_update
                    )
        logging.info(
            "iteration %d loss_value %f",
            epoch,
            sum(total_loss, 0) / len(total_loss),
        )

    return embeddings


embeddings = embed_graph(karate_graph)
# Out:
# INFO: iteration 0 loss_value 1.771314
# INFO: iteration 1 loss_value 1.658352
# INFO: iteration 2 loss_value 1.604607
# INFO: iteration 3 loss_value 1.546119
# INFO: iteration 4 loss_value 1.506840
# INFO: iteration 5 loss_value 1.437123
# INFO: iteration 6 loss_value 1.405791
# INFO: iteration 7 loss_value 1.378170
# INFO: iteration 8 loss_value 1.369926
# INFO: iteration 9 loss_value 1.359530
# INFO: iteration 10 loss_value 1.378218
# INFO: iteration 11 loss_value 1.388711
# INFO: iteration 12 loss_value 1.318382
# INFO: iteration 13 loss_value 1.299767
# INFO: iteration 14 loss_value 1.328728
# INFO: iteration 15 loss_value 1.301325
# INFO: iteration 16 loss_value 1.300106
# INFO: iteration 17 loss_value 1.287544
# INFO: iteration 18 loss_value 1.288304
# INFO: iteration 19 loss_value 1.326081
# INFO: iteration 20 loss_value 1.298692
# INFO: iteration 21 loss_value 1.261768
# INFO: iteration 22 loss_value 1.248945
# INFO: iteration 23 loss_value 1.262734
# INFO: iteration 24 loss_value 1.321558
# INFO: iteration 25 loss_value 1.263488
# INFO: iteration 26 loss_value 1.286731
# INFO: iteration 27 loss_value 1.281792
# INFO: iteration 28 loss_value 1.288809
# INFO: iteration 29 loss_value 1.267322
# INFO: iteration 30 loss_value 1.276523
# INFO: iteration 31 loss_value 1.272730
# INFO: iteration 32 loss_value 1.286185
# INFO: iteration 33 loss_value 1.250701
# INFO: iteration 34 loss_value 1.314131
# INFO: iteration 35 loss_value 1.306830
# INFO: iteration 36 loss_value 1.299489
# INFO: iteration 37 loss_value 1.278527
# INFO: iteration 38 loss_value 1.298940
# INFO: iteration 39 loss_value 1.301083
# INFO: iteration 40 loss_value 1.262723
# INFO: iteration 41 loss_value 1.284166
# INFO: iteration 42 loss_value 1.311333
# INFO: iteration 43 loss_value 1.268477
# INFO: iteration 44 loss_value 1.274106
# INFO: iteration 45 loss_value 1.287532
# INFO: iteration 46 loss_value 1.287453
# INFO: iteration 47 loss_value 1.253469
# INFO: iteration 48 loss_value 1.285637
# INFO: iteration 49 loss_value 1.276518
# INFO: iteration 50 loss_value 1.286688
# INFO: iteration 51 loss_value 1.293987
# INFO: iteration 52 loss_value 1.302704
# INFO: iteration 53 loss_value 1.282502
# INFO: iteration 54 loss_value 1.309013
# INFO: iteration 55 loss_value 1.285710
# INFO: iteration 56 loss_value 1.316287
# INFO: iteration 57 loss_value 1.278265
# INFO: iteration 58 loss_value 1.307701
# INFO: iteration 59 loss_value 1.308296
# INFO: iteration 60 loss_value 1.296579
# INFO: iteration 61 loss_value 1.297901
# INFO: iteration 62 loss_value 1.306415
# INFO: iteration 63 loss_value 1.279997
# INFO: iteration 64 loss_value 1.334312
# INFO: iteration 65 loss_value 1.281189
# INFO: iteration 66 loss_value 1.309571
# INFO: iteration 67 loss_value 1.297185
# INFO: iteration 68 loss_value 1.259739
# INFO: iteration 69 loss_value 1.280654
# INFO: iteration 70 loss_value 1.297236
# INFO: iteration 71 loss_value 1.285597
# INFO: iteration 72 loss_value 1.284722
# INFO: iteration 73 loss_value 1.302565
# INFO: iteration 74 loss_value 1.329540
# INFO: iteration 75 loss_value 1.306315
# INFO: iteration 76 loss_value 1.298234
# INFO: iteration 77 loss_value 1.293712
# INFO: iteration 78 loss_value 1.312331
# INFO: iteration 79 loss_value 1.300635
# INFO: iteration 80 loss_value 1.350093
# INFO: iteration 81 loss_value 1.314422
# INFO: iteration 82 loss_value 1.289438
# INFO: iteration 83 loss_value 1.318053
# INFO: iteration 84 loss_value 1.318903
# INFO: iteration 85 loss_value 1.326336
# INFO: iteration 86 loss_value 1.278329
# INFO: iteration 87 loss_value 1.291282
# INFO: iteration 88 loss_value 1.293485
# INFO: iteration 89 loss_value 1.288205
# INFO: iteration 90 loss_value 1.258366
# INFO: iteration 91 loss_value 1.323316
# INFO: iteration 92 loss_value 1.270070
# INFO: iteration 93 loss_value 1.280143
# INFO: iteration 94 loss_value 1.290278
# INFO: iteration 95 loss_value 1.289200
# INFO: iteration 96 loss_value 1.319051
# INFO: iteration 97 loss_value 1.321536
# INFO: iteration 98 loss_value 1.288906
# INFO: iteration 99 loss_value 1.303522

# %%
import matplotlib.patches as mpatches


def plot_graph(embeddings):
    colors = {1: "b", 2: "r"}
    group_1 = mpatches.Patch(color=colors[1], label="Group 1")
    group_2 = mpatches.Patch(color=colors[2], label="Group 2")

    circle = visualization.PoincareDisk(coords_type="ball")

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    circle.set_ax(ax)
    circle.draw(ax=ax)
    for i_embedding, embedding in enumerate(embeddings):
        x = embedding[0]
        y = embedding[1]
        pt_id = i_embedding
        plt.scatter(x, y, c=colors[karate_graph.labels[pt_id][0]], s=150)
        ax.annotate(pt_id, (x, y))

    plt.tick_params(which="both")
    plt.title("Poincare Ball Embedding of the Karate Club Network")
    plt.legend(handles=[group_1, group_2])
    plt.show()


plot_graph(embeddings)

# %%
# Now try this with another dataset

from geomstats.datasets.utils import load_random_graph

randg = load_random_graph()
randg_embedding = embed_graph(randg)
plot_graph(randg_embedding)
# Out:
# INFO: iteration 0 loss_value 1.879719
# INFO: iteration 1 loss_value 1.764710
# INFO: iteration 2 loss_value 1.678932
# INFO: iteration 3 loss_value 1.693109
# INFO: iteration 4 loss_value 1.592424
# INFO: iteration 5 loss_value 1.532137
# INFO: iteration 6 loss_value 1.485895
# INFO: iteration 7 loss_value 1.427980
# INFO: iteration 8 loss_value 1.433133
# INFO: iteration 9 loss_value 1.443724
# INFO: iteration 10 loss_value 1.433814
# INFO: iteration 11 loss_value 1.359036
# INFO: iteration 12 loss_value 1.418302
# INFO: iteration 13 loss_value 1.394516
# INFO: iteration 14 loss_value 1.428955
# INFO: iteration 15 loss_value 1.363950
# INFO: iteration 16 loss_value 1.357374
# INFO: iteration 17 loss_value 1.377301
# INFO: iteration 18 loss_value 1.299857
# INFO: iteration 19 loss_value 1.343722
# INFO: iteration 93 loss_value 1.274368
# INFO: iteration 94 loss_value 1.292384
# INFO: iteration 95 loss_value 1.282506
# INFO: iteration 96 loss_value 1.288908
# INFO: iteration 97 loss_value 1.326504
# INFO: iteration 98 loss_value 1.319799
# INFO: iteration 99 loss_value 1.285228

# %%
# # Embed polblogs


# def load_polblogs(path):
#     with open(path, "r") as f:
#         lines = f.readlines()
#     lines = lines[2:]
#     edges = []
#     for line in lines:
#         in_id, out_id, num_edges = line.split(" ")
#         for i in range(int(num_edges)):
#             edges.append([int(in_id) - 1, int(out_id) - 1])
#     edges = np.array(edges)
#     n_nodes = np.max(edges) + 1
#     graph = nx.Graph()
#     graph.add_nodes_from(range(n_nodes))
#     graph.add_edges_from(edges)
#     return graph

# polblogs_graph = load_polblogs(polblogs_path)

# nx.draw_networkx(polblogs_graph, with_labels=False, node_size=5)
import pandas as pd

adjacency = pd.read_table(
    "data/polblogs/raw/adjacency.tsv", header=None, usecols=[0, 1]
)
names = pd.read_table("data/polblogs/raw/names.tsv", header=None)
labels = pd.read_table("data/polblogs/raw/labels.tsv", header=None)
names_labels = pd.read_table("data/polblogs/raw/names_labels.tsv", header=None)

polblogs_graph = nx.from_pandas_edgelist(adjacency, source=0, target=1)
polblogs_graph.add_nodes_from(names.index)

nx.draw_networkx(
    polblogs_graph,
    with_labels=False,
    node_size=5,
    node_color=labels[0].reindex(polblogs_graph.nodes),  # Ordering
)

# %%
# Convert to geomstats graph

from geomstats.datasets.prepare_graph_data import Graph, HyperbolicEmbedding


def nx_to_geomstats(graph, labels, drop_isolated=True):
    out_graph = load_karate_graph()  # Need a starter graph
    out_graph.n_nodes = graph.number_of_nodes()
    out_graph.n_edges = graph.number_of_edges()
    out_graph.edges = {
        node: list(graph.neighbors(node)) for node in graph.nodes
    }
    out_graph.labels = labels[0].reindex(polblogs_graph.nodes)

    if drop_isolated:
        for node in reversed(list(out_graph.edges.keys())):
            if len(out_graph.edges[node]) == 0:
                # del out_graph.edges[node]
                # del out_graph.labels[node]
                # out_graph.n_nodes -= 1
                # Add self-edge instead
                out_graph.edges[node] = [node]

    return out_graph


polblogs_graph_geom = nx_to_geomstats(polblogs_graph, labels)

# %%
# Embed

hyp_emb = HyperbolicEmbedding(dim=8, n_negative=16, n_context=16, lr=0.01)
polblogs_graph_embedded = hyp_emb.embed(polblogs_graph_geom)

plt.scatter(
    polblogs_graph_embedded[:, 0],
    polblogs_graph_embedded[:, 1],
    c=polblogs_graph_geom.labels,
)
# Out:
# INFO: Number of edges: 1490
# INFO: Mean vertices by edges: 22.616778523489934
# INFO: iteration 0 loss_value 2.828093
# INFO: iteration 1 loss_value 2.456290
# INFO: iteration 2 loss_value 2.375300
# INFO: iteration 3 loss_value 2.313872
# INFO: iteration 4 loss_value 2.245689
# INFO: iteration 5 loss_value 2.166830
# INFO: iteration 6 loss_value 2.105531
# INFO: iteration 7 loss_value 2.042090
# INFO: iteration 8 loss_value 1.994340
# INFO: iteration 9 loss_value 1.948531
# INFO: iteration 10 loss_value 1.925913
# INFO: iteration 85 loss_value 1.749835
# INFO: iteration 86 loss_value 1.746614
# INFO: iteration 87 loss_value 1.752290
# INFO: iteration 88 loss_value 1.740883
# INFO: iteration 89 loss_value 1.742083
# INFO: iteration 90 loss_value 1.747625
# INFO: iteration 91 loss_value 1.743329
# INFO: iteration 92 loss_value 1.749714
# INFO: iteration 93 loss_value 1.750578
# INFO: iteration 94 loss_value 1.751917
# INFO: iteration 95 loss_value 1.744765
# INFO: iteration 96 loss_value 1.744479
# INFO: iteration 97 loss_value 1.748917
# INFO: iteration 98 loss_value 1.744645
# INFO: iteration 99 loss_value 1.747974

# %%
import pickle as pkl

with open("data/polblogs/processed/embed_8d.pkl", "wb") as f:
    pkl.dump(polblogs_graph_embedded, f)

# %%
# Convert to hyperboloid


def to_hyperboloid_points(poincare_pts):
    """
    Post: result.shape[1] == poincare_pts.shape[1] + 1
    """
    norm_sqd = (poincare_pts ** 2).sum(axis=1)
    N = poincare_pts.shape[1]
    result = np.zeros((poincare_pts.shape[0], N + 1), dtype=np.float64)
    result[:, :N] = (2.0 / (1 - norm_sqd))[:, np.newaxis] * poincare_pts
    result[:, N] = (1 + norm_sqd) / (1 - norm_sqd)
    return result


polblogs_graph_hyperboloid = to_hyperboloid_points(polblogs_graph_embedded)

polblogs_graph_hyperboloid.shape
# Out:
# (1490, 9)

# %%
# Try classifying hyp_emb now

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC  # SVM

from src.tree import HyperbolicDecisionTreeClassifier
from src.forest import HyperbolicRandomForestClassifier

# From https://github.com/drewwilimitis/hyperbolic-learning
from hyperbolic_learning.hyperbolic_svm.hsvm import LinearHSVM

from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import accuracy_score

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    polblogs_graph_hyperboloid,
    np.array(polblogs_graph_geom.labels),
    test_size=0.2,
    random_state=42,
)
# X_train, X_test, y_train, y_test = pkl.load(
#     open("data/polblogs/hsvm_data.pkl", "rb")
# )

# Hyperparameters
MIN_SAMPLES = 2
MAX_DEPTH = 10
NUM_ESTIMATORS = 100  # Keep it small, for speedup
JOBS = -1
USE_TQDM = True
args = dict(
    min_samples_split=MIN_SAMPLES,
    min_samples_leaf=MIN_SAMPLES,
    max_depth=MAX_DEPTH,
)

# Fit a regular decision tree
dt = DecisionTreeClassifier(**args)
dt.fit(X_train, y_train)

# Fit a hyperbolic decision tree
hdt = HyperbolicDecisionTreeClassifier(hyperbolic=True, **args)
hdt.fit(X_train, y_train)

# Control dt
hdt_control = HyperbolicDecisionTreeClassifier(hyperbolic=False, **args)
hdt_control.fit(X_train, y_train)

# Sklearn random forest
rf = RandomForestClassifier(n_estimators=NUM_ESTIMATORS, **args)
rf.fit(X_train, y_train)

# Hyperbolic random forest
hrf = HyperbolicRandomForestClassifier(
    n_estimators=NUM_ESTIMATORS, hyperbolic=True, **args
)
hrf.fit(X_train, y_train, n_jobs=JOBS, use_tqdm=USE_TQDM)

# Control hrf
hrf_control = HyperbolicRandomForestClassifier(
    n_estimators=NUM_ESTIMATORS, hyperbolic=False, **args
)
hrf_control.fit(X_train, y_train, n_jobs=JOBS, use_tqdm=USE_TQDM)

# Regular SVM
svm = SVC()
svm.fit(X_train, y_train)

# hSVM
hsvm = LinearHSVM(early_stopping=np.inf, num_epochs=1000)
hsvm.fit(X_train, y_train)

# Compare scores
print(
    f"Regular decision tree accuracy: {accuracy_score(y_test, dt.predict(X_test)):.3f}",
    f"Hyperbolic decision tree accuracy: {accuracy_score(y_test, hdt.predict(X_test)):.3f}",
    f"Hyperbolic decision tree accuracy (control): {accuracy_score(y_test, hdt_control.predict(X_test)):.3f}",
    "",
    f"Random forest accuracy: {accuracy_score(y_test, rf.predict(X_test)):.3f}",
    f"Hyperbolic random forest accuracy: {accuracy_score(y_test, hrf.predict(X_test)):.3f}",
    f"Hyperbolic random forest accuracy (control): {accuracy_score(y_test, hrf_control.predict(X_test)):.3f}",
    "",
    f"SVM accuracy: {accuracy_score(y_test, svm.predict(X_test)):.3f}",
    f"hSVM accuracy: {accuracy_score(y_test, hsvm.predict(X_test)):.3f}",
    sep="\n",
)
# Out:
# 100%|██████████| 100/100 [00:35<00:00,  2.83it/s]
# 100%|██████████| 100/100 [00:46<00:00,  2.15it/s]
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# Regular decision tree accuracy: 0.624
# Hyperbolic decision tree accuracy: 0.681
# Hyperbolic decision tree accuracy (control): 0.540
#
# Random forest accuracy: 0.674
# Hyperbolic random forest accuracy: 0.718
# Hyperbolic random forest accuracy (control): 0.537
#
# SVM accuracy: 0.594
# hSVM accuracy: 0.503

# %%
# This takes about 10 minutes

vals = pd.DataFrame(columns=["name", "trial", "score"])
for predictor, name in zip(
    [dt, hdt, hdt_control, rf, hrf, hrf_control, svm],
    [
        "Decision Tree",
        "Hyperbolic Decision Tree",
        "Control Decision Tree",
        "Random Forest",
        "Hyperbolic Random Forest",
        "Control Random Forest",
        "SVM",
    ],
):
    fit_params = {}
    if name in ["Hyperbolic Random Forest", "Control Random Forest"]:
        fit_params = {"use_tqdm": True, "n_jobs": -1}
    scores = cross_val_score(
        predictor,
        X_train,
        y_train,
        cv=10,
        fit_params=fit_params,
    )
    vals = pd.concat(
        [
            vals,
            pd.DataFrame(
                [[name, i, score] for i, score in enumerate(scores)],
                columns=["name", "trial", "score"],
            ),
        ]
    )

vals
# Out:
# 100%|██████████| 100/100 [00:30<00:00,  3.23it/s]
# 100%|██████████| 100/100 [00:32<00:00,  3.12it/s]
# 100%|██████████| 100/100 [00:31<00:00,  3.15it/s]
# 100%|██████████| 100/100 [00:32<00:00,  3.05it/s]
# 100%|██████████| 100/100 [00:33<00:00,  2.95it/s]
# 100%|██████████| 100/100 [00:32<00:00,  3.05it/s]
# 100%|██████████| 100/100 [00:31<00:00,  3.13it/s]
# 100%|██████████| 100/100 [00:32<00:00,  3.09it/s]
# 100%|██████████| 100/100 [00:33<00:00,  2.96it/s]
# 100%|██████████| 100/100 [00:33<00:00,  3.01it/s]
# 100%|██████████| 100/100 [00:41<00:00,  2.39it/s]
# 100%|██████████| 100/100 [00:42<00:00,  2.33it/s]
# 100%|██████████| 100/100 [00:41<00:00,  2.39it/s]
# 100%|██████████| 100/100 [00:39<00:00,  2.51it/s]
# 100%|██████████| 100/100 [00:37<00:00,  2.68it/s]
# 100%|██████████| 100/100 [00:40<00:00,  2.48it/s]
# 100%|██████████| 100/100 [00:40<00:00,  2.47it/s]
# 100%|██████████| 100/100 [00:39<00:00,  2.55it/s]
# 100%|██████████| 100/100 [00:39<00:00,  2.52it/s]
# 100%|██████████| 100/100 [00:39<00:00,  2.55it/s]
#              name trial     score
# 0   Decision Tree     0  0.525000
# 1   Decision Tree     1  0.583333
# 2   Decision Tree     2  0.697479
# 3   Decision Tree     3  0.563025
# 4   Decision Tree     4  0.689076
# ..            ...   ...       ...
# 5             SVM     5  0.613445
# 6             SVM     6  0.546218
# 7             SVM     7  0.647059
# 8             SVM     8  0.596639
# 9             SVM     9  0.571429
#
# [70 rows x 3 columns]

# %%
# Can't use hsvm with cross_val_score, so do it manually:
splits = KFold(n_splits=10).split(X_train)
for split in splits:
    X_train_split, X_val_split = X_train[split[0]], X_train[split[1]]
    y_train_split, y_val_split = y_train[split[0]], y_train[split[1]]
    hsvm.fit(X_train_split, y_train_split)
    vals = pd.concat(
        [
            vals,
            pd.DataFrame(
                [
                    [
                        "Hyperbolic SVM",
                        i,
                        hsvm.score(X_val_split, y_val_split),
                    ]
                    for i in range(5)
                ],
                columns=["name", "trial", "score"],
            ),
        ]
    )
vals
# Out:
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/phil/mambaforge/envs/hdt/lib/python3.11/site-packages/sklearn/svm/_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/phil/hdt/hyperbolic_learning/hyperbolic_svm/hsvm.py:84: RuntimeWarning: invalid value encountered in sqrt
#   proj_w[0] = np.sqrt(np.sum(proj_w[1:] ** 2) - eps)
#               name trial     score
# 0    Decision Tree     0  0.525000
# 1    Decision Tree     1  0.583333
# 2    Decision Tree     2  0.697479
# 3    Decision Tree     3  0.563025
# 4    Decision Tree     4  0.689076
# ..             ...   ...       ...
# 0   Hyperbolic SVM     0  0.487395
# 1   Hyperbolic SVM     1  0.487395
# 2   Hyperbolic SVM     2  0.487395
# 3   Hyperbolic SVM     3  0.487395
# 4   Hyperbolic SVM     4  0.487395
#
# [120 rows x 3 columns]

# %%
order = []

means = vals.groupby("name").mean()
stds = vals.groupby("name").std()

# Compute 95% confidence intervals
intervals = 1.96 * stds["score"] / np.sqrt(10)

# Sort by mean score
means = means.sort_values(by="score", ascending=False)
stds = stds.loc[means.index]

# fig = plt.figure(figsize=(15, 10))
# plt.barh(
#     means.index,
#     means.score,
#     xerr=intervals,
#     capsize=5,
# )
# # plt.xticks(rotation=90)

# # Add statistical significance stars
# for i, (mean1, interval1) in enumerate(zip(means.score, intervals)):
#     for j, (mean2, interval2) in enumerate(zip(means.score, intervals)):
#         if mean1 >

# Seaborn plot with stars
import seaborn as sns

fig = plt.figure(figsize=(15, 10))
ax = sns.barplot(
    y=means.score,
    x=means.index,
    yerr=intervals,
    capsize=5,
    order=means.index,
)
plt.xlabel("Accuracy")
plt.xticks(rotation=90)
# plt.ylabel("Classifier")
plt.title("Benchmark: Polblogs embeddings, 8-D hyperbolic space")

# Make background transparent
fig.patch.set_alpha(0.0)

# Bigger fonts
plt.rcParams.update({"font.size": 20})
